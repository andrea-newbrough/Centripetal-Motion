# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
x = radius_array
y = tsquared_array

tsquared_array = np.array([1.77, 1.69, 1.61, 1.37])
radius_array = np.array([ 0.2040, 
                        0.1870, 0.1680, 0.1560 ])
m, b = np.polyfit(x, y, 1)


print(m)
print(b)

plt.plot(x, y, 'o')
plt.plot(x, m*x + b)

plt.xlabel('radium (m)')
plt.ylabel('T^2 (s)')
plt.title('radius versus T squared graph')
# Out:
# 7.589169000933711
# 0.25343604108309986
# Text(0.5, 1.0, 'radius versus T sqaured graph')
